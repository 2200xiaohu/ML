# %%
import dabl
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('./Data/train.csv')
test = pd.read_csv('./Data/pre_contest_test.csv')

# %% [markdown]
# # 自动清洗数据

# %%
clean_data = dabl.clean(train, verbose=1)

# %% [markdown]
# # 画图

# %%
dabl.plot(train, "label")
# Out:
# d:\python\envs\automl\lib\site-packages\dabl\plot\supervised.py:622: FutureWarning: The second positional argument of plot is a Series 'y'. If passing a column name, use a keyword.
#   warnings.warn("The second positional argument of plot is a Series 'y'."
# d:\python\envs\automl\lib\site-packages\dabl\plot\utils.py:692: UserWarning: Dropped 34 outliers in column feature61.
#   warn("Dropped {} outliers in column {}.".format(
# d:\python\envs\automl\lib\site-packages\dabl\plot\utils.py:692: UserWarning: Dropped 7 outliers in column feature21.
#   warn("Dropped {} outliers in column {}.".format(
# d:\python\envs\automl\lib\site-packages\dabl\plot\utils.py:692: UserWarning: Dropped 41 outliers in column feature26.
#   warn("Dropped {} outliers in column {}.".format(
# d:\python\envs\automl\lib\site-packages\dabl\plot\utils.py:692: UserWarning: Dropped 43 outliers in column feature27.
#   warn("Dropped {} outliers in column {}.".format(
# ...
